# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, marker = 'o')#we can use argument marker to emphasize with each point with specified marker.
plt.show()

# %%
# format strings "fmt" - marker|line|color
import matplotlib.pyplot as plt
import numpy as np

# %%
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, "o:r")
plt.show()

# %%
# Line Refrenence
#1) - solid line
#2) : dotted line
#3) -- dashed line
#4) -. dashline/dotted line

# %%
# Color Refrenence
#1) r red
#2) g green
#3) b blue
#4) c Cyan
#5) y yellow
#6) k black
#7) w white

# %%
# marker size - ms

import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %%
#marker edge color - mec
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, marker = 'o', ms = 20, mec = "r")
plt.show()

# %%
#marker face color - mfc
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, marker = 'o', ms = 20, mec = "r", mfc = "r")
plt.show()
